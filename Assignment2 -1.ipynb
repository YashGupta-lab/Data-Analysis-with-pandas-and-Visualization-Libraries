# %% [markdown]
# # Name:- Yash Gupta
# # Roll NO. :- 2301560069
# # Course :- MCA sec:-A
# # Subject :- AIML

# %% [markdown]
# # General Pandas Exercise

# %% [markdown]
# # Exercise 1: From the given dataset print the first and last five rows

# %%
import pandas as pd
df = pd.read_csv("E:\\KRMU\\Subject\\Aiml\\Assignment 2\\Automobile_data.csv")
df.head(5)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
import pandas as pd
df = pd.read_csv("E:\\KRMU\\Subject\\Aiml\\Assignment 2\\Automobile_data.csv")
df.tail(5)
# Out:
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# 58     86  volkswagen      sedan        97.3   171.7         ohc
# 59     87       volvo      sedan       104.3   188.8         ohc
# 60     88       volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 56             four          85               27   7975.0
# 57             four          52               37   7995.0
# 58             four         100               26   9995.0
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %% [markdown]
# # Exercise 2: Clean the dataset and update the CSV file

# %%
df = pd.read_csv("E:\\KRMU\\Subject\\Aiml\\Assignment 2\\Automobile_data.csv", na_values={
'price':["?","n.a"],
'stroke':["?","n.a"],
'horsepower':["?","n.a"],
'peak-rpm':["?","n.a"],
'average-mileage':["?","n.a"]})
print (df)

df.to_csv("E:\\KRMU\\Subject\\Aiml\\Assignment 2\\Automobile_data.csv")
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %% [markdown]
# # Exercise 3: Find the most expensive car company name

# %%
import pandas as pd
df = pd.read_csv("E:\\KRMU\\Subject\\Aiml\\Assignment 2\\Automobile_data.csv")
df = df [['company','price']][df.price==df['price'].max()]
df
# Out:
#           company    price
# 35  mercedes-benz  45400.0

# %% [markdown]
# # Exercise 4: Print All volvo Cars details

# %%
import pandas as pd
df = pd.read_csv("E:\\KRMU\\Subject\\Aiml\\Assignment 2\\Automobile_data.csv")
car_Manufacturers = df.groupby('company')
toyotaDf = car_Manufacturers.get_group('volvo')
toyotaDf
# Out:
#     Unnamed: 0  index company body-style  wheel-base  length engine-type  \
# 59          59     87   volvo      sedan       104.3   188.8         ohc
# 60          60     88   volvo      wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 59             four         114               23  12940.0
# 60             four         114               23  13415.0

# %% [markdown]
# # Exercise 5: Count total cars per company

# %%
import pandas as pd
df = pd.read_csv("E:\\KRMU\\Subject\\Aiml\\Assignment 2\\Automobile_data.csv")
df['company'].value_counts()
# Out:
# company
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# mitsubishi       4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# honda            3
# isuzu            3
# jaguar           3
# porsche          3
# dodge            2
# volvo            2
# Name: count, dtype: int64

# %% [markdown]
# # Exercise 6: Find each company’s Higesht price car

# %%
import pandas as pd

df = pd.read_csv("E:\\KRMU\\Subject\\Aiml\\Assignment 2\\Automobile_data.csv")

priceDf = df.groupby('company')['price'].max().reset_index()

print(priceDf)
# Out:
#           company    price
# 0     alfa-romero  16500.0
# 1            audi  18920.0
# 2             bmw  41315.0
# 3       chevrolet   6575.0
# 4           dodge   6377.0
# 5           honda  12945.0
# 6           isuzu   6785.0
# 7          jaguar  36000.0
# 8           mazda  18344.0
# 9   mercedes-benz  45400.0
# 10     mitsubishi   8189.0
# 11         nissan  13499.0
# 12        porsche  37028.0
# 13         toyota  15750.0
# 14     volkswagen   9995.0
# 15          volvo  13415.0

# %% [markdown]
# # Exercise 7: Find the average mileage of each car making company

# %%
import pandas as pd

df = pd.read_csv("E:\\KRMU\\Subject\\Aiml\\Assignment 2\\Automobile_data.csv")

mileageDf = df.groupby('company')['average-mileage'].mean().reset_index()

print(mileageDf)
# Out:
#           company  average-mileage
# 0     alfa-romero        20.333333
# 1            audi        20.000000
# 2             bmw        19.000000
# 3       chevrolet        41.000000
# 4           dodge        31.000000
# 5           honda        26.333333
# 6           isuzu        33.333333
# 7          jaguar        14.333333
# 8           mazda        28.000000
# 9   mercedes-benz        18.000000
# 10     mitsubishi        29.500000
# 11         nissan        31.400000
# 12        porsche        17.000000
# 13         toyota        28.714286
# 14     volkswagen        31.750000
# 15          volvo        23.000000

# %% [markdown]
# # Exercise 8: Sort all cars by Price column

# %%
import pandas as pd
carsDf = pd.read_csv("E:\\KRMU\\Subject\\Aiml\\Assignment 2\\Automobile_data.csv")
carsDf = carsDf.sort_values(by=['price', 'horsepower'], ascending=False)
carsDf.head(5)
# Out:
#     Unnamed: 0  index        company   body-style  wheel-base  length  \
# 35          35     47  mercedes-benz      hardtop       112.0   199.2
# 11          11     14            bmw        sedan       103.5   193.8
# 34          34     46  mercedes-benz        sedan       120.9   208.1
# 46          46     62        porsche  convertible        89.5   168.9
# 12          12     15            bmw        sedan       110.0   197.0
#
#    engine-type num-of-cylinders  horsepower  average-mileage    price
# 35        ohcv            eight         184               14  45400.0
# 11         ohc              six         182               16  41315.0
# 34        ohcv            eight         184               14  40960.0
# 46        ohcf              six         207               17  37028.0
# 12         ohc              six         182               15  36880.0

# %% [markdown]
# # Exercise 9: Concatenate two data frames using the following conditions

# %%
import pandas as pd

GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}
carsDf1 = pd.DataFrame.from_dict(GermanCars)

japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}
carsDf2 = pd.DataFrame.from_dict(japaneseCars)

carsDf = pd.concat([carsDf1, carsDf2], keys=["Germany", "Japan"])
carsDf
# Out:
#                Company   Price
# Germany 0         Ford   23845
#         1     Mercedes  171995
#         2          BMV  135925
#         3         Audi   71400
# Japan   0       Toyota   29995
#         1        Honda   23600
#         2       Nissan   61500
#         3  Mitsubishi    58900

# %% [markdown]
# # Exercise 10: Merge two data frames using the following condition

# %%
import pandas as pd

Car_Price = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'Price': [23845, 17995, 135925 , 71400]}
carPriceDf = pd.DataFrame.from_dict(Car_Price)

car_Horsepower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 'horsepower': [141, 80, 182 , 160]}
carsHorsepowerDf = pd.DataFrame.from_dict(car_Horsepower)

carsDf = pd.merge(carPriceDf, carsHorsepowerDf, on="Company")
carsDf
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160
